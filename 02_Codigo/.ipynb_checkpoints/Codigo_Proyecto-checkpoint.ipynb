# %% [markdown]
# # Modelo para el Analisis de factores que influyen en la popularidad de los videojuegos
#
# Institucion: Escuela Politecnica Nacional EPN
# Materia: Metodos Numericos
# Semestre: 2026-A
# Estudiantes:
# * Ricardo Cisneros
# * Hugo Coyago
# * Jair Paez
#
# ---

# %%
"""Importa las bibliotecas requeridas para el proyecto."""
import os
import csv
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parte 1: Unificacion del Dataset
# En esta etapa, reconstruimos el dataset a partir de los datos crudos extraidos de Steam y SteamSpy.

# %%
def analizar_rango_dueños(cadena_dueños: str) -> "int | str":
    """
    Calcula el punto medio del rango de dueños estimados.

    Args:
        cadena_dueños (str): Cadena de texto con el rango de dueños (ej. "10,000 .. 20,000").
        
    Returns:
        "int | str": El punto medio del rango como valor entero, o una cadena vacía en caso de error.
    """
    if not cadena_dueños or '..' not in cadena_dueños:
        return ""
    partes = cadena_dueños.split('..')
    if len(partes) == 2:
        try:
            limite_inferior = int(partes[0].replace(',', '').strip())
            limite_superior = int(partes[1].replace(',', '').strip())
            return (limite_inferior + limite_superior) // 2
        except ValueError:
            return ""
    return ""

def extraer_año_lanzamiento(fecha_str: str) -> str:
    """
    Extrae el año de lanzamiento desde una fecha dada en formato texto.

    Args:
        fecha_str (str): Cadena de texto que contiene la fecha de lanzamiento.

    Returns:
        str: El año extraído (ej. "2015"), o una cadena vacía si no se encuentra coincidencia.
    """
    if not fecha_str or fecha_str == "\\N":
        return ""
    coincidencia = re.search(r'\b(19\d\d|20\d\d)\b', fecha_str)
    if coincidencia:
        return coincidencia.group(1)
    return ""

def unificar_dataset() -> str:
    """
    Ejecuta la unificación de todos los datos en un solo conjunto de datos consolidados.

    Returns:
        str: La ruta del archivo CSV donde se guardaron los datos unificados.
    """
    print("Iniciando unificación de datos...")

    directorio_base = ".."
    juegos_csv = os.path.join(directorio_base, "01_Datos", "Datos crudos", "steam-insights-main", "games", "games.csv")
    reseñas_csv = os.path.join(directorio_base, "01_Datos", "Datos crudos", "steam-insights-main", "reviews", "reviews.csv")
    steamspy_csv = os.path.join(directorio_base, "01_Datos", "Datos crudos", "steam-insights-main", "steamspy_insights", "steamspy_insights.csv")
    categorias_csv = os.path.join(directorio_base, "01_Datos", "Datos crudos", "steam-insights-main", "categories", "categories.csv")
    salida_datos_unificados_crudos = os.path.join(directorio_base, "01_Datos", "steam_raw_unified_all_columns.csv")

    """Carga las categorías por aplicación."""
    datos_categorias = {}
    with open(categorias_csv, mode='r', encoding='utf-8') as archivo_cat:
        lector = csv.DictReader(archivo_cat)
        for fila in lector:
            id_app = fila.get("app_id")
            if id_app:
                datos_categorias[id_app] = datos_categorias.get(id_app, 0) + 1

    """Carga los datos principales de los juegos."""
    datos_juegos = {}
    with open(juegos_csv, mode='r', encoding='utf-8') as archivo_juegos:
        lector = csv.DictReader(archivo_juegos)
        for fila in lector:
            id_aplicacion = fila.get("app_id")
            if not id_aplicacion:
                continue
            
            idiomas_str = fila.get("languages", "").strip()
            cant_idiomas = 0
            if idiomas_str and idiomas_str != "\\N":
                cant_idiomas = len([lang.strip() for lang in idiomas_str.split(",") if lang.strip()])

            es_gratis_str = fila.get("is_free", "").strip().lower()
            es_gratis_num = 1 if es_gratis_str in ["true", "1"] else (0 if es_gratis_str in ["false", "0"] else "")

            datos_juegos[id_aplicacion] = {
                "name": fila.get("name", ""),
                "release_date": fila.get("release_date", ""),
                "release_year": extraer_año_lanzamiento(fila.get("release_date", "")),
                "is_free": es_gratis_num,
                "price_overview": fila.get("price_overview", ""),
                "games_languages": fila.get("languages", ""),
                "language_count": cant_idiomas,
                "type": fila.get("type", "")
            }

    """Carga las reseñas de los usuarios."""
    datos_reseñas = {}
    with open(reseñas_csv, mode='r', encoding='utf-8') as archivo_reseñas:
        lector = csv.DictReader(archivo_reseñas)
        for fila in lector:
            id_aplicacion = fila.get("app_id")
            if not id_aplicacion:
                continue
            datos_reseñas[id_aplicacion] = {
                "review_score": fila.get("review_score", ""),
                "review_score_description": fila.get("review_score_description", ""),
                "reviews_positive": fila.get("positive", ""),
                "reviews_negative": fila.get("negative", ""),
                "reviews_total": fila.get("total", ""),
                "metacritic_score": fila.get("metacritic_score", ""),
                "reviews_text": fila.get("reviews", ""),
                "recommendations": fila.get("recommendations", ""),
                "steamspy_user_score": fila.get("steamspy_user_score", ""),
                "steamspy_score_rank": fila.get("steamspy_score_rank", ""),
                "reviews_steamspy_positive": fila.get("steamspy_positive", ""),
                "reviews_steamspy_negative": fila.get("steamspy_negative", "")
            }

    """Carga las métricas de SteamSpy usando Pandas con soporte de escape de caracteres."""
    datos_steamspy = {}
    todos_los_ids_aplicacion = set(datos_juegos.keys()) | set(datos_reseñas.keys())
    
    df_spy_raw = pd.read_csv(steamspy_csv, dtype=str, escapechar='\\')
    for _, fila_spy in df_spy_raw.iterrows():
        fila = fila_spy.to_dict()
        id_aplicacion = fila.get("app_id")
        if not id_aplicacion:
            continue
        datos_steamspy[id_aplicacion] = fila
        todos_los_ids_aplicacion.add(id_aplicacion)

    """Unifica los datos en un solo conjunto."""
    todos_los_datos_fusionados = []
    for id_aplicacion in sorted(list(todos_los_ids_aplicacion), key=lambda x: int(x) if x.isdigit() else 9999999):
        juego = datos_juegos.get(id_aplicacion, {
            "name": "", "release_date": "", "release_year": "", "is_free": "", "price_overview": "",
            "games_languages": "", "language_count": "", "type": ""
        })
        reseña = datos_reseñas.get(id_aplicacion, {
            "review_score": "", "review_score_description": "", "reviews_positive": "", "reviews_negative": "",
            "reviews_total": "", "metacritic_score": "", "reviews_text": "", "recommendations": "",
            "steamspy_user_score": "", "steamspy_score_rank": "", "reviews_steamspy_positive": "", "reviews_steamspy_negative": ""
        })
        spy = datos_steamspy.get(id_aplicacion, {
            "developer": "", "publisher": "", "owners_range": "", "concurrent_users_yesterday": "",
            "playtime_average_forever": "", "playtime_average_2weeks": "", "playtime_median_forever": "",
            "playtime_median_2weeks": "", "price": "", "initial_price": "", "discount": "", "languages": "", "genres": ""
        })

        """Convierte los precios a dólares."""
        precio_dolares = ""
        if spy.get("price", "") and spy.get("price", "") != "\\N":
            try:
                precio_dolares = round(int(spy.get("price", "")) / 100.0, 2)
            except ValueError:
                pass

        precio_inicial_dolares = ""
        if spy.get("initial_price", "") and spy.get("initial_price", "") != "\\N":
            try:
                precio_inicial_dolares = round(int(spy.get("initial_price", "")) / 100.0, 2)
            except ValueError:
                pass

        """Calcula la proporción de aprobación."""
        proporcion_aprobacion = ""
        if reseña.get("reviews_positive", "") and reseña.get("reviews_negative", ""):
            try:
                positivas = int(reseña.get("reviews_positive", ""))
                negativas = int(reseña.get("reviews_negative", ""))
                if positivas + negativas > 0:
                    proporcion_aprobacion = round(positivas / (positivas + negativas), 4)
            except ValueError:
                pass

        """Genera la fila unificada."""
        fila_fusionada = {
            "app_id": id_aplicacion,
            "name": juego["name"],
            "release_date": juego["release_date"],
            "release_year": juego["release_year"],
            "is_free": juego["is_free"],
            "price_overview": juego["price_overview"],
            "games_languages": juego["games_languages"],
            "language_count": juego["language_count"],
            "category_count": datos_categorias.get(id_aplicacion, 0),
            "type": juego["type"],
            "developer": spy.get("developer", ""),
            "publisher": spy.get("publisher", ""),
            "owners_range": spy.get("owners_range", ""),
            "concurrent_users_yesterday": spy.get("concurrent_users_yesterday", ""),
            "playtime_average_forever": spy.get("playtime_average_forever", ""),
            "playtime_average_2weeks": spy.get("playtime_average_2weeks", ""),
            "playtime_median_forever": spy.get("playtime_median_forever", ""),
            "playtime_median_2weeks": spy.get("playtime_median_2weeks", ""),
            "steamspy_price": spy.get("price", ""),
            "steamspy_initial_price": spy.get("initial_price", ""),
            "steamspy_discount": spy.get("discount", ""),
            "steamspy_languages": spy.get("languages", ""),
            "genres": spy.get("genres", ""),
            "review_score": reseña["review_score"],
            "review_score_description": reseña["review_score_description"],
            "reviews_positive": reseña["reviews_positive"],
            "reviews_negative": reseña["reviews_negative"],
            "reviews_total": reseña["reviews_total"],
            "metacritic_score": reseña["metacritic_score"],
            "reviews_text": reseña["reviews_text"],
            "recommendations": reseña["recommendations"],
            "steamspy_user_score": reseña["steamspy_user_score"],
            "steamspy_score_rank": reseña["steamspy_score_rank"],
            "reviews_steamspy_positive": reseña["reviews_steamspy_positive"],
            "reviews_steamspy_negative": reseña["reviews_steamspy_negative"],
            "price_usd": precio_dolares,
            "steamspy_initial_price_usd": precio_inicial_dolares,
            "approval_ratio": proporcion_aprobacion,
            "estimated_owners": analizar_rango_dueños(spy.get("owners_range", ""))
        }
        todos_los_datos_fusionados.append(fila_fusionada)

    """Exporta los datos a un archivo CSV."""
    encabezados = list(todos_los_datos_fusionados[0].keys())
    with open(salida_datos_unificados_crudos, mode='w', newline='', encoding='utf-8') as archivo_salida:
        escritor = csv.DictWriter(archivo_salida, fieldnames=encabezados)
        escritor.writeheader()
        escritor.writerows(todos_los_datos_fusionados)

    print("Consolidación completada con éxito.")
    return salida_datos_unificados_crudos

# Ejecución de la función principal de la Parte 1
archivo_unificado = unificar_dataset()
# Out:
# Iniciando unificación de datos...
# Consolidación completada con éxito.

# %% [markdown]
# # Parte 2: Limpieza de Datos
#
# Proceso de limpieza y tratamiento de nulos.

# %%
def limpiar_datos(ruta_archivo: str) -> "tuple[pd.DataFrame, list[str]]":
    """
    Limpia los datos, procesa nulos y filtra variables independientes de alta calidad.

    Args:
        ruta_archivo (str): Ruta al archivo CSV con los datos crudos unificados.

    Returns:
        "tuple[pd.DataFrame, list[str]]": Un DataFrame limpio y la lista de variables clave.
    """
    df = pd.read_csv(ruta_archivo, dtype={'app_id': str}, low_memory=False)

    """Define las variables clave del modelo predictivo."""
    variable_objetivo = 'estimated_owners'
    variables_predictoras = [
        'price_usd', 'is_free', 'approval_ratio', 'reviews_total',
        'language_count', 'category_count', 'release_year'
    ]
    todas_las_variables = [variable_objetivo] + variables_predictoras

    """Limpia los registros duplicados."""
    df = df.drop_duplicates(subset=['app_id'])

    """Convierte los valores nulos a NaN y elimina las filas incompletas."""
    for col in todas_las_variables:
            df[col] = df[col].replace([r'\\N', 'N/A', 'nan', 'NaN', ''], np.nan)
            df[col] = pd.to_numeric(df[col], errors='coerce')

    df_limpio = df.dropna(subset=todas_las_variables).copy()

    """Filtra los valores incoherentes (precios negativos, variables fuera de rango)."""
    df_limpio = df_limpio[
        (df_limpio['price_usd'] >= 0) &
        (df_limpio['is_free'].isin([0.0, 1.0, 0, 1])) &
        (df_limpio['reviews_total'] >= 0) &
        (df_limpio['language_count'] >= 0) &
        (df_limpio['category_count'] >= 0) &
        (df_limpio['release_year'] >= 1997) & (df_limpio['release_year'] <= 2024) &
        (df_limpio['approval_ratio'] >= 0.0) & (df_limpio['approval_ratio'] <= 1.0) &
        (df_limpio['estimated_owners'] > 0)
    ]
    
    """Filtra el dataset para conservar unicamente las 8 variables clave del modelo."""
    df_limpio = df_limpio[todas_las_variables]
    
    print("Limpieza de datos completada.")
    return df_limpio, todas_las_variables

# Ejecución de la función principal de la Parte 2
df_limpio, todas_las_variables = limpiar_datos(archivo_unificado)
# Out:
# Limpieza de datos completada.

# %% [markdown]
# # Parte 3: Normalizacion de Datos
#
# Escalamiento de variables (Z-Score).

# %%
def normalizar_datos(df_limpio: pd.DataFrame, todas_las_variables: "list[str]") -> "tuple[pd.DataFrame, list[str]]":
    """
    Normaliza los datos numéricos y exporta el conjunto final a un CSV.

    Args:
        df_limpio (pd.DataFrame): DataFrame con los datos previamente limpiados.
        todas_las_variables ("list[str]"): Lista de las variables clave del dataset.

    Returns:
        "tuple[pd.DataFrame, list[str]]": El DataFrame con variables normalizadas y la lista de variables numéricas procesadas.
    """
    
    """Normaliza las variables usando el metodo Z-score."""
    variables_numericas = todas_las_variables
    for col in variables_numericas:
        mean_val = df_limpio[col].mean()
        std_val = df_limpio[col].std()
        df_limpio[col + '_normalized'] = (df_limpio[col] - mean_val) / std_val if std_val > 0.0 else 0.0

    """Exporta las variables del modelo limpio a un archivo CSV."""
    directorio_base = ".."
    archivo_salida = os.path.join(directorio_base, "01_Datos", "steam_cleaned_data.csv")
    df_limpio[todas_las_variables].to_csv(archivo_salida, index=False)
    
    print("Normalización completada y exportada con éxito.")
    return df_limpio, variables_numericas

# Ejecución de la función principal de la Parte 3
df_final, variables_numericas = normalizar_datos(df_limpio, todas_las_variables)
df_final.head()
# Out:
# Normalización completada y exportada con éxito.
#    estimated_owners  price_usd  is_free  approval_ratio  reviews_total  \
# 0        15000000.0       9.99      0.0          0.9743       241610.0
# 1         7500000.0       4.99      0.0          0.8699         8409.0
# 2         7500000.0       4.99      0.0          0.9029         6921.0
# 3         7500000.0       4.99      0.0          0.8291         3066.0
# 4         3500000.0       4.99      0.0          0.9525        23374.0
#
#    language_count  category_count  release_year  estimated_owners_normalized  \
# 0             1.0               6        2000.0                    14.996682
# 1             1.0               7        1999.0                     7.448984
# 2             1.0               3        2003.0                     7.448984
# 3             1.0               7        2001.0                     7.448984
# 4             1.0               5        1999.0                     3.423544
#
# ...

# %%
def formatear_numero(valor: float) -> str:
    """
    Formatea los valores numericos para evitar la notacion cientifica.

    Args:
        valor (float): Valor numerico a formatear.

    Returns:
        str: Valor formateado como texto.
    """
    if pd.isna(valor):
        return ""
    if float(valor).is_integer():
        return f"{valor:.0f}"
    return f"{valor:.4f}".rstrip("0").rstrip(".")


"""Configura Pandas para mostrar numeros sin notacion cientifica."""
pd.set_option("display.float_format", formatear_numero)


def analisis_exploratorio(df_final: pd.DataFrame, variables_numericas: "list[str]") -> pd.DataFrame:
    """
    Realiza el analisis exploratorio de las variables numericas del modelo.

    Args:
        df_final (pd.DataFrame): DataFrame final con los datos limpios y normalizados.
        variables_numericas ("list[str]"): Lista de variables numericas a analizar.

    Returns:
        pd.DataFrame: Tabla resumen con las principales medidas estadisticas.
    """
    """Selecciona unicamente las variables numericas existentes en el DataFrame."""
    variables_analisis = [columna for columna in variables_numericas if columna in df_final.columns]
    datos_analisis = df_final[variables_analisis].copy()

    """Construye la tabla resumen con medidas descriptivas principales."""
    resumen_datos = pd.DataFrame({
        "conteo": datos_analisis.count(),
        "media": datos_analisis.mean(),
        "mediana": datos_analisis.median(),
        "moda": datos_analisis.mode(dropna=True).iloc[0],
        "minimo": datos_analisis.min(),
        "maximo": datos_analisis.max(),
        "desviacion estandar": datos_analisis.std()
    })

    print("Resumen exploratorio de los datos")
    display(resumen_datos)

    """Genera histogramas de frecuencia para cada variable numerica."""
    for columna in variables_analisis:
        datos_columna = datos_analisis[columna].dropna()

        plt.figure(figsize=(8, 4))
        plt.hist(datos_columna, bins=30)
        plt.title(f"Histograma de {columna}")
        plt.xlabel(columna)
        plt.ylabel("Frecuencia")
        plt.grid(True)
        plt.tight_layout()
        plt.show()

    return resumen_datos


# Ejecucion de la funcion principal del analisis exploratorio
tabla_resumen = analisis_exploratorio(df_final, variables_numericas)
# Out:
# Resumen exploratorio de los datos
#                   conteo      media  mediana  moda  minimo   maximo  \
# estimated_owners   79215 98091.0812    10000 10000   10000 75000000
# price_usd          79215      7.936     4.99  4.99       0      999
# is_free            79215     0.0973        0     0       0        1
# approval_ratio     79215     0.7501   0.8081     1       0        1
# reviews_total      79215  1200.3228       24     1       1  2448273
# language_count     79215     1.2185        1     1       0      103
# category_count     79215     4.3117        4     2       0       23
# release_year       79215  2019.9725     2020  2023    1997     2024
#
#                   desviacion estandar
# estimated_owners          993680.3924
# price_usd                     12.5062
# is_free                        0.2963
# approval_ratio                  0.241
# reviews_total              17122.0305
# language_count                 2.1085
# category_count                 2.6905
# ...

# %% [markdown]
# # Parte 4: Barajeo y Division del Dataset (70/15/15)
#
# Para garantizar la validez del modelo y evitar sesgos de ordenamiento, primero barajamos el dataset.
# Luego, dividimos los datos de acuerdo a lo propuesto en el informe:
# - **70% de los datos** para el entrenamiento y ajuste del modelo ($X_{train}, y_{train}$).
# - **15% de los datos** para validacion/testeo ($X_{val}, y_{val}$).
# - **15% de los datos** para pruebas finales ($X_{test}, y_{test}$).
#
# Planteamos el sistema de ecuaciones normales únicamente sobre el conjunto de entrenamiento:
# $$
# A \cdot c = b
# $$
# Donde $A = X_{train}^T X_{train}$ y $b = X_{train}^T y_{train}$.

# %%
def dividir_dataset(df_final: pd.DataFrame, todas_las_variables: "list[str]", semilla: int = 87) -> "tuple[np.ndarray, np.ndarray, pd.DataFrame, pd.DataFrame]":
    """
    Baraja el dataset y realiza la division 70/15/15, construyendo la matriz A y vector b de entrenamiento.

    Args:
        df_final (pd.DataFrame): DataFrame con los datos normalizados.
        todas_las_variables ("list[str]"): Lista de las variables clave del dataset.
        semilla (int): Semilla aleatoria para garantizar reproducibilidad.

    Returns:
        "tuple[np.ndarray, np.ndarray, pd.DataFrame, pd.DataFrame]": Matriz A, Vector b de entrenamiento, y DataFrames de validacion y pruebas.
    """
    # 1. Barajeo con semilla aleatoria fija para reproducibilidad
    df_shuffled = df_final.sample(frac=1, random_state=semilla).reset_index(drop=True)
    N = len(df_shuffled)

    # 2. Limites de division
    limite_train = int(0.70 * N)
    limite_val = int(0.85 * N)

    # 3. Division del dataset
    df_train = df_shuffled.iloc[:limite_train].copy()
    df_val = df_shuffled.iloc[limite_train:limite_val].copy()
    df_test = df_shuffled.iloc[limite_val:].copy()

    print(f"Registros Totales: {N}")
    print(f"Registros Entrenamiento (70%): {len(df_train)}")
    print(f"Registros Validacion (15%): {len(df_val)}")
    print(f"Registros Pruebas Finales (15%): {len(df_test)}")

    # 4. Construccion de matrices sobre el conjunto de ENTRENAMIENTO
    variable_objetivo = 'estimated_owners_normalized'
    variables_predictoras = [col + '_normalized' for col in todas_las_variables if col != 'estimated_owners']

    y_train = df_train[variable_objetivo].values
    N_train = len(y_train)
    ones_train = np.ones((N_train, 1))
    X_train_preds = df_train[variables_predictoras].values
    X_train = np.hstack((ones_train, X_train_preds))

    # Ecuaciones normales: A = X_train^T * X_train  y  b = X_train^T * y_train
    A = np.dot(X_train.T, X_train)
    b = np.dot(X_train.T, y_train)

    print(f"\nMatriz A (X_train^T * X_train) de dimensiones {A.shape} construida.")
    print(f"Vector b (X_train^T * y_train) de dimensiones {b.shape} construido.")
    
    return A, b, df_val, df_test

# Ejecucion de la funcion principal de la Parte 4
A, b, df_val, df_test = dividir_dataset(df_final, todas_las_variables)
# Out:
# Registros Totales: 79215
# Registros Entrenamiento (70%): 55450
# Registros Validacion (15%): 11882
# Registros Pruebas Finales (15%): 11883
#
# Matriz A (X_train^T * X_train) de dimensiones (8, 8) construida.
# Vector b (X_train^T * y_train) de dimensiones (8,) construido.

# %% [markdown]
# # Parte 5: Implementacion de los Solucionadores Numericos
#
# Para resolver el sistema de ecuaciones normales $A \cdot c = b$, implementamos desde cero dos metodos de resolucion directa cubiertos en el silabo:
# 1. **Eliminacion Gaussiana con Pivoteo Parcial**
# 2. **Descomposicion LU (Doolittle)**
#
# Ambos metodos estan programados de forma nativa en Python sin usar `scipy.linalg` o `numpy.linalg.solve` para garantizar el enfoque puramente numerico de la materia.

# %%
def resolver_eliminacion_gaussiana(A_in: np.ndarray, b_in: np.ndarray) -> np.ndarray:
    """
    Resuelve el sistema A * c = b usando el metodo de Eliminacion Gaussiana con pivoteo parcial.

    Args:
        A_in (np.ndarray): Matriz de coeficientes del sistema.
        b_in (np.ndarray): Vector de terminos independientes.

    Returns:
        np.ndarray: Vector de coeficientes solucion c.
    """
    A = A_in.copy().astype(float)
    b = b_in.copy().astype(float)
    n = len(b)
    
    # Eliminacion hacia adelante
    for i in range(n):
        max_row = i + np.argmax(np.abs(A[i:n, i]))
        if A[max_row, i] == 0:
            raise ValueError("La matriz del sistema es singular.")
        if max_row != i:
            A[[i, max_row]] = A[[max_row, i]]
            b[[i, max_row]] = b[[max_row, i]]
            
        for j in range(i + 1, n):
            factor = A[j, i] / A[i, i]
            A[j, i:] -= factor * A[i, i:]
            b[j] -= factor * b[i]
            
    # Sustitucion hacia atras
    c = np.zeros(n)
    for i in range(n - 1, -1, -1):
        c[i] = (b[i] - np.dot(A[i, i+1:], c[i+1:])) / A[i, i]
    return c

def resolver_lu(A_in: np.ndarray, b_in: np.ndarray) -> np.ndarray:
    """
    Resuelve el sistema A * c = b usando el metodo de descomposicion LU (Doolittle).
    """
    A = A_in.copy().astype(float)
    b = b_in.copy().astype(float)
    n = len(b)
    
    L = np.eye(n)
    U = np.zeros((n, n))
    
    for i in range(n):
        for k in range(i, n):
            s = sum(L[i, j] * U[j, k] for j in range(i))
            U[i, k] = A[i, k] - s
        for k in range(i + 1, n):
            s = sum(L[k, j] * U[j, i] for j in range(i))
            L[k, i] = (A[k, i] - s) / U[i, i]
            
    y_temp = np.zeros(n)
    for i in range(n):
        y_temp[i] = b[i] - sum(L[i, j] * y_temp[j] for j in range(i))
        
    c = np.zeros(n)
    for i in range(n - 1, -1, -1):
        c[i] = (y_temp[i] - sum(U[i, j] * c[j] for j in range(i + 1, n))) / U[i, i]
        
    return c

# Resuelve el sistema utilizando el conjunto de entrenamiento
c_gauss = resolver_eliminacion_gaussiana(A, b)
c_lu = resolver_lu(A, b)

# Muestra la tabla de coeficientes ajustados
    # Definir variables_predictoras globalmente para evitar NameError
variables_predictoras = [col + '_normalized' for col in todas_las_variables if col != 'estimated_owners']
variables_modelo = ['Intercepto (a0)'] + variables_predictoras
print(f"{'-'*65}\n{'Variable del Modelo':<30} | {'Eliminacion Gauss.':<15} | {'Descomposicion LU':<15}\n{'-'*65}")
for var, coef_g, coef_lu in zip(variables_modelo, c_gauss, c_lu):
    print(f"{var:<30} | {coef_g:<15.6f} | {coef_lu:<15.6f}")
print('-'*65)
# Out:
# -----------------------------------------------------------------
# Variable del Modelo            | Eliminacion Gauss. | Descomposicion LU
# -----------------------------------------------------------------
# Intercepto (a0)                | 0.001622        | 0.001622
# price_usd_normalized           | 0.013637        | 0.013637
# is_free_normalized             | 0.014070        | 0.014070
# approval_ratio_normalized      | 0.004908        | 0.004908
# reviews_total_normalized       | 0.798873        | 0.798873
# language_count_normalized      | 0.028020        | 0.028020
# category_count_normalized      | 0.024269        | 0.024269
# release_year_normalized        | -0.034036       | -0.034036
# -----------------------------------------------------------------

# %% [markdown]
# # Parte 6: Evaluacion del Modelo
#
# En esta etapa se evalua el rendimiento del modelo numerico utilizando los subconjuntos de validacion y prueba. Para ello, se emplean los coeficientes obtenidos mediante los solucionadores numericos directos y se calculan las metricas de MAE, RMSE y R².
#
# Estas metricas permiten medir que tan cercanas son las predicciones del modelo respecto a los valores reales de popularidad normalizada.

# %%
def construir_matriz_prediccion(df_datos: pd.DataFrame, todas_las_variables: "list[str]") -> "tuple[np.ndarray, np.ndarray]":
    """
    Construye la matriz de prediccion X y el vector real y para evaluar el modelo.

    Args:
        df_datos (pd.DataFrame): Subconjunto de datos utilizado para la evaluacion.
        todas_las_variables ("list[str]"): Lista de variables originales del modelo.

    Returns:
        "tuple[np.ndarray, np.ndarray]": Matriz de diseño para prediccion y vector de valores reales.
    """
    variable_objetivo = 'estimated_owners_normalized'
    variables_predictoras = [col + '_normalized' for col in todas_las_variables if col != 'estimated_owners']

    """Extrae los valores reales de la variable objetivo."""
    y_real = df_datos[variable_objetivo].values

    """Construye la matriz de diseño agregando la columna de unos para el intercepto."""
    matriz_unos = np.ones((len(df_datos), 1))
    matriz_predictoras = df_datos[variables_predictoras].values
    matriz_diseño = np.hstack((matriz_unos, matriz_predictoras))

    return matriz_diseño, y_real


def calcular_metricas(y_real: np.ndarray, y_predicho: np.ndarray) -> "tuple[float, float, float]":
    """
    Calcula las metricas de evaluacion del modelo de regresion.

    Args:
        y_real (np.ndarray): Vector con los valores reales de la variable objetivo.
        y_predicho (np.ndarray): Vector con los valores estimados por el modelo.

    Returns:
        "tuple[float, float, float]": Valores de MAE, RMSE y R2.
    """
    """Calcula los errores entre los valores reales y los valores predichos."""
    errores = y_real - y_predicho

    """Calcula el error absoluto medio."""
    mae = np.mean(np.abs(errores))

    """Calcula la raiz del error cuadratico medio."""
    rmse = np.sqrt(np.mean(errores ** 2))

    """Calcula el coeficiente de determinacion R2."""
    suma_residuos = np.sum(errores ** 2)
    suma_total = np.sum((y_real - np.mean(y_real)) ** 2)
    r2 = 1 - (suma_residuos / suma_total) if suma_total != 0 else 0.0

    return mae, rmse, r2


def evaluar_modelo_validacion(df_val: pd.DataFrame, todas_las_variables: "list[str]", coeficientes: np.ndarray) -> pd.DataFrame:
    """
    Evalua el modelo numerico utilizando el subconjunto de validacion.

    Args:
        df_val (pd.DataFrame): Subconjunto de validacion.
        todas_las_variables ("list[str]"): Lista de variables originales del modelo.
        coeficientes (np.ndarray): Vector de coeficientes obtenidos en la resolucion del sistema.

    Returns:
        pd.DataFrame: Tabla con las metricas de evaluacion del modelo.
    """
    """Construye la matriz de prediccion y obtiene los valores reales de validacion."""
    matriz_val, y_val_real = construir_matriz_prediccion(df_val, todas_las_variables)

    """Calcula los valores predichos mediante el producto entre la matriz de diseño y los coeficientes."""
    y_val_predicho = np.dot(matriz_val, coeficientes)

    """Calcula las metricas de evaluacion sobre el conjunto de validacion."""
    mae_val, rmse_val, r2_val = calcular_metricas(y_val_real, y_val_predicho)

    """Organiza los resultados en una tabla."""
    tabla_metricas = pd.DataFrame({
        "conjunto": ["validacion"],
        "mae": [mae_val],
        "rmse": [rmse_val],
        "r2": [r2_val]
    })

    print("Metricas de evaluacion del modelo")
    display(tabla_metricas)

    return tabla_metricas


# Ejecucion de la funcion principal de evaluacion
tabla_metricas = evaluar_modelo_validacion(df_val, todas_las_variables, c_gauss)
# Out:
# Metricas de evaluacion del modelo
#      conjunto    mae   rmse     r2
# 0  validacion 0.0673 0.3295 0.7843

# %% [markdown]
# # Parte 7: Análisis de Residuos e Identificación de Valores Atípicos
#
# En esta etapa se analizan los residuos del modelo, es decir, la diferencia entre los valores reales y los valores predichos. Esto permite observar en qué casos el modelo presenta mayores errores de predicción.
#
# Además, se identifican registros atípicos dentro del conjunto de validación, tomando como referencia los residuos estandarizados. Estos casos permiten reconocer videojuegos cuyo comportamiento no es completamente explicado por el modelo lineal construido.

# %%
def analizar_residuos_validacion(df_val: pd.DataFrame, todas_las_variables: "list[str]", coeficientes: np.ndarray, limite_desviacion: float = 2.0) -> "tuple[pd.DataFrame, pd.DataFrame]":
    """
    Analiza los residuos del modelo sobre el subconjunto de validacion e identifica valores atipicos.

    Args:
        df_val (pd.DataFrame): Subconjunto de validacion.
        todas_las_variables ("list[str]"): Lista de variables originales del modelo.
        coeficientes (np.ndarray): Vector de coeficientes obtenidos en la resolucion del sistema.
        limite_desviacion (float): Limite usado para identificar residuos atipicos.

    Returns:
        "tuple[pd.DataFrame, pd.DataFrame]": Tabla completa de residuos y tabla de valores atipicos.
    """
    """Construye la matriz de prediccion y obtiene los valores reales de validacion."""
    matriz_val, y_val_real = construir_matriz_prediccion(df_val, todas_las_variables)

    """Calcula los valores predichos mediante el modelo."""
    y_val_predicho = np.dot(matriz_val, coeficientes)

    """Calcula los residuos y los errores absolutos."""
    residuos = y_val_real - y_val_predicho
    errores_absolutos = np.abs(residuos)

    """Crea una copia del conjunto de validacion para agregar los resultados del analisis."""
    tabla_residuos = df_val.copy()
    tabla_residuos["valor_real"] = y_val_real
    tabla_residuos["valor_predicho"] = y_val_predicho
    tabla_residuos["residuo"] = residuos
    tabla_residuos["error_absoluto"] = errores_absolutos

    """Calcula la media y desviacion estandar de los residuos."""
    media_residuos = tabla_residuos["residuo"].mean()
    desviacion_residuos = tabla_residuos["residuo"].std()

    """Calcula los residuos estandarizados para identificar errores atipicos."""
    tabla_residuos["residuo_estandarizado"] = (tabla_residuos["residuo"] - media_residuos) / desviacion_residuos if desviacion_residuos > 0.0 else 0.0

    """Genera una tabla resumen con las principales medidas de los residuos."""
    resumen_residuos = pd.DataFrame({
        "media": [tabla_residuos["residuo"].mean()],
        "mediana": [tabla_residuos["residuo"].median()],
        "desviacion_estandar": [tabla_residuos["residuo"].std()],
        "minimo": [tabla_residuos["residuo"].min()],
        "maximo": [tabla_residuos["residuo"].max()],
        "mae": [tabla_residuos["error_absoluto"].mean()]
    })

    print("Resumen de residuos")
    display(resumen_residuos)

    """Define las columnas que se mostraran en la tabla de mayores errores."""
    columnas_mostrar = todas_las_variables + [
        "valor_real",
        "valor_predicho",
        "residuo",
        "error_absoluto",
        "residuo_estandarizado"
    ]

    """Ordena y muestra los registros con mayor error absoluto."""
    mayores_errores = tabla_residuos[columnas_mostrar].sort_values(
        by="error_absoluto",
        ascending=False
    ).head(10)

    print("Registros con mayor error absoluto")
    display(mayores_errores)

    """Identifica los valores atipicos segun el residuo estandarizado."""
    tabla_atipicos = tabla_residuos[
        np.abs(tabla_residuos["residuo_estandarizado"]) >= limite_desviacion
    ].copy()

    """Ordena los valores atipicos desde el mayor error absoluto hasta el menor."""
    tabla_atipicos = tabla_atipicos[columnas_mostrar].sort_values(
        by="error_absoluto",
        ascending=False
    )

    print(f"Valores atipicos detectados con |residuo_estandarizado| >= {limite_desviacion}")
    print(f"Cantidad de valores atipicos detectados: {len(tabla_atipicos)}")

    """Grafica el histograma de residuos."""
    plt.figure(figsize=(8, 4))
    plt.hist(tabla_residuos["residuo"], bins=30)
    plt.title("Histograma de residuos")
    plt.xlabel("Residuo")
    plt.ylabel("Frecuencia")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    """Grafica los valores reales frente a los valores predichos."""
    limite_minimo = min(y_val_real.min(), y_val_predicho.min())
    limite_maximo = max(y_val_real.max(), y_val_predicho.max())

    plt.figure(figsize=(6, 6))
    plt.scatter(y_val_real, y_val_predicho, alpha=0.4)
    plt.plot([limite_minimo, limite_maximo], [limite_minimo, limite_maximo], linestyle="--")
    plt.title("Valores reales vs valores predichos")
    plt.xlabel("Valor real")
    plt.ylabel("Valor predicho")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    """Grafica los residuos frente a los valores predichos."""
    plt.figure(figsize=(8, 4))
    plt.scatter(y_val_predicho, residuos, alpha=0.4)
    plt.axhline(0, linestyle="--")
    plt.title("Residuos vs valores predichos")
    plt.xlabel("Valor predicho")
    plt.ylabel("Residuo")
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    return tabla_residuos, tabla_atipicos


# Ejecucion de la funcion principal de analisis de residuos
tabla_residuos, tabla_atipicos = analizar_residuos_validacion(
    df_val,
    todas_las_variables,
    c_gauss
);
# Out:
# Resumen de residuos
#     media  mediana  desviacion_estandar   minimo  maximo    mae
# 0 -0.0074  -0.0132               0.3294 -17.0461 17.4108 0.0673
# Registros con mayor error absoluto
#        estimated_owners  price_usd  is_free  approval_ratio  reviews_total  \
# 60482          35000000          0        1            0.82         374122
# 64303          35000000      39.99        0          0.8709        1116345
# 59287          15000000      24.99        0          0.9377          94593
# 66622          15000000          0        1          0.7748         143342
# 61081           7500000      23.99        0           0.816         320637
# 56313          35000000          0        1          0.8007         613924
# 64347           7500000          0        0          0.8925          31739
# 57189          15000000      29.99        0          0.9613         199747
# 56736           1500000      49.99        0           0.879         121426
# ...
